# %% [markdown]
# # Assignment 1

# %% [markdown]
# Due by 11:59pm, Feb. 16, 2024

# %% [markdown]
# **Name:** Debasrita Sarkar

# %% [markdown]
# **ID (A\\#): A20544597**

# %% [markdown]
# ## Theory Questions (Question 4 is worth 8 points, other question is worth 4 points)

# %% [markdown]
# 1. Explain the differences between supervised, semi-surpervised, weakly-supervised and unsupervised learning.

# %% [markdown]
# **Answer:**
#
# Supervised learning is a type of machine learning algorithm that learns from labeled data. The machine learns the relationship between input features and corresponding outputs.
#
# Semi- supervised learning is a type of machine learning that uses both labeled and unlabeled data to train a model for classification or regression tasks. It is useful when there is a lot of unlabeled data available compared to the labeled data.
#
# Weakly supervised learning is a type of machine learning trained with partial or noisy labels, which are less precise than fully labeled data.
#
# Unsupervised learning is a type of learning where the algorithm is given data without explicit labels. The system tries to find patterns, relationships, or structures in the data without being told what to look for.

# %% [markdown]
# 2. Explain the difference between regression and classification.

# %% [markdown]
# **Answer:**
# Classification is the process of finding or discovering a model or function that helps in separating the data into multiple categorical classes i.e. discrete values. Eg: male or female, pass or fail, low medium or high.
#
# Regression is the process of finding a model or function for distinguishing the data into continuous real values instead of using classes or discrete values. Eg: price, height or weight trend

# %% [markdown]
# 3. Explain how to perform N-fold cross-validation.

# %% [markdown]
# **Answer:**
# N-fold cross-validation is a technique used in machine learning to assess the performance and generalization ability of a model. It involves splitting the dataset into N subsets/folds, training the model on N-1 folds, and validating on the remaining fold. This process is repeated N times, each time using a different fold as the validation set.

# %% [markdown]
# 4. Bayes rule:
#
# John owns a retail store for selling phones. The phones are manufactured at three different factories, A, B, C, where factory A, B, and C produces 10%, 30%, and 60% of the phone being sold at John’s store. The probabilities of the defective phones from stores A, B, and C are 2%, 1%, and 3%, respectively. The total number of phones being sold at John’s store is 10,000. One day, a customer walks up to John’s store, and ask for a refund for a defective phone.
#
#         1. What is the probability of a phone being defective?
#
#         2. What is the probability that this defective phone is manufactured at factory A?
#
#         3. What is the probability that this defective phone is manufactured at factory B?
#
#         4. What is the probability that this defective phone is manufactured at factory C?

# %% [markdown]
# **Answer:**
# 1.
# P(D) = P(D|A)P(A)+P(D|B)P(B)+P(D|C)P(C)
# P(A) = 0.1 P(B) = 0.3 P(C) = 0.6
# P(D|A) = 0.02 P(D|B) = 0.01 P(D|C) = 0.03
#
# Therefore, P(D) = 0.02*0.1+0.3*0.01+0.6*0.03
#                 =0.023
#                 =2.3
#
#
# 2.
# P(A|D) = (P(A)*P(A|D))/P(D)
#        = (0.1*0.02)/0.023
#        = 0.0869
#        = 8.69
#
#
# 3.
# P(B|D) = (P(B)*P(B|D))/P(D)
#        = (0.3*0.01)/0.023
#        = 0.130
#        = 13
#
#
#
#
# 4.
# P(C|D) = (P(C)*P(C|D))/P(D)
#        = (0.6*0.03)/0.023
#        = 0.7826
#        =78.26

# %% [markdown]
# 5. Explain the standard steps to perform machine learning.

# %% [markdown]
# **Answer:**
# 1. Define the Problem
# 2. Collect and Prepare Data
# 3. Select or create relevant features (input variables) from the raw data.
# 4. Split the Data
# 5. Choose a Model
# 6. Train the Model
# 7. Evaluate Model Performance
# 8. Fine-tune the model's hyperparameters to improve performance
# 9. Validate on Test Set
# 10. Interpret and Explain
# 11. Deploy the Model
# 12. Iterate and Improve

# %% [markdown]
# 6. Let ${(x^{(i)}, y^{(i)})}_{i=1}^m$
#   be a set of training examples where  $𝑦_{𝑖}∈ℝ$
#   and  $𝑥_{𝑖}∈{ℝ}^𝑛$
#  , write a linear regression model using model parameter  $𝜃_𝑗$
#   and features  $𝑥_1,...,𝑥_𝑛$

# %% [markdown]
# **Answer:**
#
# Linear regression model for a set of training examples ${(x^{(i)}, y^{(i)})}_{i=1}^m$ where $𝑦_{𝑖}∈ℝ$
#   and  $𝑥_{𝑖}∈{ℝ}^𝑛$ using model parameter can be given by:
#
#   $h_θ(x^{(i)}) = \theta_0+\theta_1x_1^{(i)}+\theta_2x_2^{(i)}+....+\theta_nx_n^{(i)}$
#
#   where, $h_θ(x^{(i)})$: predicted output for the i-th training example
#
#    $\theta_0$: bias term
#
#    $\theta_1,\theta_2,....,\theta_n$: weights corresponding to $x_1,x_2,...,x_n$ respectively
#
#    $x_1^{(i)},x_2^{(i)},....,x_n^{(i)}$: feature for i-th training example
#
#    Considering $x_{(i)} as a column vector, adding a bias term 1, model can be expressed as:
#
#    $h_θ(x^{(i)})=\theta^{T}⋅x^{(i)}$ where $h_θ(x^{(i)})$ is a scalar representing the predicted output for the i-th training example.
#
#    $\theta$ is a column vector of parameters (including the bias term) with dimensions (n+1)×1.
#
#    $x^{(i)}$ is a column vector of features (including the bias term) with dimensions (n+1)×1
#
#    The overall linear regression model for all training examples can be represented as: $h_θ(X)=X.\theta$
#
#    where $h_θ(X)$: column vector representing the predicted outputs for all training examples.
#
#    $X$ is a matrix of input features for all training examples, where each row corresponds to a training example with the first column being 1 (bias term).
#
#    $\theta$ is a column vector of parameters (including the bias term).
#
#  This model can be used to predict the output for a set of training examples. It can be trained by minimizing the $\theta$ which is the difference between predicted and actual output values using a cost function and optimization algorithms like gradient descent.

# %% [markdown]
# 7. Write the objective function that can be used to determine the regression model parameters. How is this objective function will be used to find model parameters?

# %% [markdown]
# **Answer:**
#
# An objective function that can be used for regression is the mean squared error (MSE), which is the average of the squared differences between the predicted and true values. The MSE can be written as:
# MSE(θ)= $1/N \sum_{i=1}^{N}(f(x_i∣θ)-y_i )^2$
# where θ are the model parameters, $f(x_i∣θ)$ is the prediction for the i-th input, and $y_i$ is the true value for the i-th input.
#
# To find the optimal parameters, we can use optimization techniques such as gradient descent that iteratively update the parameters based on the gradient of the objective function. This approach involves minimizing the cost function.Gradient descent  updates the parameters as:
# $\theta \leftarrow \theta - \alpha \frac{\partial MSE(\theta)}{\partial \theta}$
# where α is the learning rate, and $\frac{\partial MSE(\theta)}{\partial \theta}$ is the gradient of the MSE with respect to the parameters. The gradient tells us the direction and magnitude of the steepest ascent of the objective function, so by moving in the opposite direction, we can reduce the objective function value.

# %% [markdown]
# 8. Let $\theta$ =[2,3,4] be the model parameters obtained for linear regression. Let $x$ =[-1,2] be a feature vector. Find the value $y$ that will be obtained by the linear regression for the feature vector $x$. ($\theta\$ denotes the bias.)

# %% [markdown]
# **Answer:**
# $x_1$ = $-1$
# $x_2$ = $2$
#
# $\theta$ = [2,3,4]
#
# Let the value y predicted by the linear regression model using the feature vector x and model parameters $\theta$ be given by:
#
# y = $\theta_0+ \theta_1.x_1+\theta_2.x_2$
#   = 2+3.(-1)+4.(2)
#   = 2-3+8
#   = 7
#
# The value $y$ that will be obtained by the linear regression is 7

# %% [markdown]
# 9. Suppose an artificial neuron has weight W = [0.2, 0.3], bias b = 0.2 and a   sigmoid activation function. If the input data = [2,3], what is the output  value of the neuron?

# %% [markdown]
# **Answer:**
#
# Output = $1/(1+e^{-z})$
#
# $z$ = $\sum_{i=1}^{2}W_i.input_i$ + $b$
#
#     = ($W_1.input_1$) + ($W_2.input_2$) + $b$
#
#     = 0.2*2 + 0.3*3 + 0.2
#
#     = 0.4 + 0.9 + 0.2
#
#     = 1.5
#
#
# Output = $1/(1+e^{-1.5})$
#
#        = 1/ 1.223
#
#        = 0.8176

# %% [markdown]
# ## Programming Questions (60 points, simple linear regression and multiple linear regression are worth 30 points, respectively)

# %% [markdown]
# In this assignment, you are going to implement your own Simple Linear Regression function and Multiple Linear Regression for the diabetes dataset.
#
# Please notice: No library versions of linear regression are allowed.

# %% [markdown]
# # 0. Load and Split data

# %%
# Do not edit the codes in this cell
# load required library\n",
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt
import numpy as np
# load dataset
X, y = load_diabetes(return_X_y=True)

# split data into train:test = 8:2
num_cases = len(y)
num_train_cases = int(num_cases*0.8)
train_X = X[:num_train_cases, :]
train_y = y[:num_train_cases]
test_X = X[num_train_cases:, :]
test_y = y[num_train_cases:]

# %%
print(load_diabetes().DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %% [markdown]
# # 1. Simple Linear Regression

# %%
# Do not edit the codes in this cell,
# Only fetch 1 attribute for simple linear regression
slr_train_X = train_X[:, 2]
slr_train_y = train_y
slr_test_X = test_X[:, 2]
slr_test_y = test_y

# %% [markdown]
# **Part I**
#
#
# Using the given dataset above, draw a scatter plot.
# 1. Plot title and xlabel, ylabel are required.
# 2. Show the plot in the Output.

# %% [markdown]
# ***Example plot***
#
# ![download (4).png](data:image/png;base64,...)

# %%
# draw the raw data plot

#Training dataset
plt.scatter(slr_train_X, slr_train_y, color='blue', label = 'Training Dataset')

#Testing dataset
plt.scatter(slr_test_X, slr_test_y, color='red', label = 'Testing Dataset')

plt.title("Scatter Plot of Training vs Testing")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.show()

# %% [markdown]
# **Part II**
#
#
# Initialize theta and construct cost function for the upcoming gradient decent.
# 1. Initialize theta, print it out
# 2. Construct Mean Square Error loss function
# 3. Calcualte the cost using initial theta, X and y, and print the result out.

# %%
#initialize theta
initial_theta = np.random.rand(2)
print("\n")
print("The initial theta value is:", initial_theta)
# Out:
# The initial theta value is: [0.24699785 0.25314525]

# %%
#define cost function
def mse_loss(X, y, theta):
    n = len(y)
    predictions = theta[0] + theta[1] * X
    error = predictions - y
    mse = (1/(2*n)) * np.sum(error**2)
    return mse

# calculate cost by calling the function and print cost results    
cost_function = mse_loss(slr_train_X, slr_train_y, initial_theta)


print("The initial cost is:", cost_function)
# Out:
# The initial cost is: 14336.896560734436

# %% [markdown]
# **Part III**
#
# Gradient descent to find the optimal fit.
# 1. Initialize learning rate and epoch, try to explain your reasons for the values chosen;
# 2. Construct gradient descent function, which updates the theta and meanwhile records all the history cost;
# 3. Call the function for the optimal fit. Print out the final theta and final cost.

# %% [markdown]
# **Question: How did you choose your lr and epoch number?**

# %% [markdown]
# **Answer:**
# I set the learning rate to be 0.8 in order to make the optimisation procedure more stable and effective, and epoch number to be 1000 to make sure the model will converge.

# %%
# gradient descent to find the optimal fit
def gradient_descent(X,y,theta,learning_rate,epochs):
    cost_history = []
    n = len(y)
    
    for epoch in range(epochs):
        predictions = theta[0] + theta[1] * X
        error = predictions - y
        
        gradient_0 = (1/n) * np.sum(error)
        gradient_1 = (1/n) * np.sum(error*X) 
        
        theta[0] = theta[0] - learning_rate * gradient_0
        theta[1] = theta[1] - learning_rate * gradient_1
        
        cost = (1/(2*n)) * np.sum(error**2)
        cost_history.append(cost)
    return theta, cost_history

# %%
epochs = 1000
learning_rate = 0.8
final_theta, cost_history = gradient_descent(slr_train_X, slr_train_y, initial_theta, learning_rate, epochs)
print("\n")
print("The final theta is: ", final_theta)
print("\n")
print("The final cost: ", cost_history[-1])
# Out:
# The final theta is:  [151.94951546 784.82978345]
#
#
# The final cost:  1953.530845766

# %% [markdown]
# **Part IV**
#
# Plot the cost for each iteration.
# 1. Plot title and xlabel, ylabel are required;
# 2. Show the plot in the Output.

# %%
#cost change for each iteration

plt.title("Cost for each iteration")
plt.plot(cost_history)
plt.xlabel("Iteration")
plt.ylabel("Cost")
# Out:
# Text(0, 0.5, 'Cost')

# %% [markdown]
# **Part V**
#
# Based on the raw data plot you already drawn, plot the final linear regression model using the final version of theta.
# 1. Plot title and xlabel, ylabel are required;
# 2. Show the plot in the Output.

# %% [markdown]
# ***Example plot***
#
# ![download (5).png](data:image/png;base64,...)

# %%
# draw the final linear model

plt.figure(figsize=(8, 6)) 
plt.title("Scatter Plot with Linear Regression Line")

plt.scatter(slr_train_X, slr_train_y, color='blue', label = 'Training Dataset')
plt.scatter(slr_test_X, slr_test_y, color='red', label = 'Testing Dataset')

x_values = np.linspace(slr_train_X.min(), slr_train_X.max(), 100)
final_regression_line = final_theta[0] + final_theta[1] * x_values
plt.plot(x_values, final_regression_line, color='orange', label='Final Regression Line')

plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.legend()
plt.show()

# %% [markdown]
# **Part VI**
#
# Using the final simple linear regression model (the final theta) to predict the slr_test_X. And then calculate the mse loss between the predictions and the slr_test_y.

# %%
# calculate the mse loss between the predictions of the slr_test_X and the slr_test_y.

predictions = final_theta[0] + final_theta[1] * slr_test_X
print("Prediction for test data:", predictions)

#mse loss
mse_test = np.mean((predictions - slr_test_y)**2)
print("\n")
print("MSE Loss between predictions of slr_test_X and slr_test_y:", mse_test)
# Out:
# Prediction for test data: [108.16754306 187.68205061 144.54120077 125.93142241 191.06564668
#   85.32826961 156.383787   168.22637323 146.2329988  234.20649652
#  132.69861454 147.07889782 121.70192732 259.58346702 285.80633653
#  153.84608995 181.7607575  106.47574503 144.54120077 133.54451355
#  143.69530175 125.08552339 149.61659487 205.44592996 159.76738307
#  153.84608995 121.70192732 172.45586832  81.94467355 199.52463684
#  129.31501847 128.46911946 136.92810962 120.01012929 163.99687815
#  132.69861454 153.00019093 206.29182898  97.17085584 128.46911946
#  115.78063421 166.5345752  153.00019093 127.62322044 148.77069585
#  163.99687815 169.91817127 187.68205061 116.62653322 125.93142241
#  228.28520341 194.44924275 248.5867798   88.71186568 224.90160734
#  112.39703814 142.84940274 130.16091749 197.83283881 218.98031423
#  151.3083929  157.22968602 158.92148405 214.75081914 207.98362701
#  132.69861454 109.01344207 123.39372536 164.84277717 213.05902111
# ...

# %% [markdown]
# # 2. Multiple Linear Regression

# %%
# Do not edit the codes in this cell
# select 8 specific columns as attributes

cols = [0,2,3,4,5,6,8,9]

# Fetch 8 attributes for multiple linear regression
mlr_train_X = train_X[:, cols]
mlr_train_y = train_y[:]

mlr_test_X = test_X[:, cols]
mlr_test_y = test_y[:]

# %% [markdown]
# **Part I**
#
# Initialize theta and construct cost function for the upcoming gradient decent.
# 1. Initialize theta, print it out;
# 2. Construct Mean Square Error loss function;
# 3. Calcualte the cost using initial theta, X and y, and print the result out.

# %%
# initialize theta
initial_theta_mlr = np.random.rand(len(cols))
print("\n")
print("The initial theta for mlr is:", initial_theta_mlr)
# Out:
# The initial theta for mlr is: [0.43718762 0.4077982  0.79954934 0.63373421 0.33318071 0.39204571
#  0.09325048 0.34206154]

# %%
# define cost function

def mse_loss(X,y,theta):
    n = len(y)
    predictions = np.dot(X, theta)
    error = predictions - y
    mse = (1/(2*n)) * np.sum(error**2)
    return mse

# calculate cost by calling the function
cost_mlr = mse_loss(mlr_train_X, mlr_train_y, initial_theta_mlr)

print("\n")
print("The cost for mlr is: ", cost_mlr)
# Out:
# The cost for mlr is:  14371.515592229092

# %% [markdown]
# **Part II**
#
# Gradient descent to find the optimal fit.
# 1. Initialize learning rate and epoch, try to explain your reasons for the values chosen;
# 2. Construct gradient descent function, which updates the theta and meanwhile records all the history cost;
# 3. Call the function for the optimal fit. Print out the final theta and final cost.

# %% [markdown]
# **Question: How did you choose your lr and epoch number?**

# %% [markdown]
# **Answer:**
#
# Chose epochs = 1003 in order to prevent the model from overfitting and to see if the model performance is improving and
# learning_rate_mlr = 0.8 to help the model to converge

# %%
# gradient descent to find the optimal fit

def grad_descent_mlr(X,y,theta,learning_rate,epochs):
    cost_history = []
    
    for epoch in range(epochs):
        predictions = np.dot(X, theta)      
       # y_reshaped = y.reshape(-1,1)    
        errors = predictions - y      
        gradients = (1 / len(y)) * np.dot(X.T, errors) 
        theta = theta - learning_rate * gradients  
        cost = mse_loss(X, y, theta)
        cost_history.append(cost)
    return theta, cost_history

# %%
epochs = 1003
learning_rate_mlr = 0.8 

final_theta_mlr, cost_history_mlr = grad_descent_mlr(mlr_train_X, mlr_train_y, initial_theta_mlr, learning_rate_mlr, epochs)
print("\n")
print("Final theta for MLR is: ", final_theta_mlr)
print("\n")
print("The final cost for mlr: ", cost_history_mlr[-1])
# Out:
# Final theta for MLR is:  [  50.60150546  427.60381885  278.48888963   -2.60635011  -36.49101145
#  -223.92876985  393.95231016   95.38107648]
#
#
# The final cost for mlr:  13076.85295701035

# %% [markdown]
# **Part III**
#
# Plot the cost for each iteration.
# 1. Plot title and xlabel, ylabel are required;
# 2. Show the plot in the Output.

# %%
# draw the cost change

plt.figure(figsize=(8,6))
plt.plot(cost_history_mlr)
plt.title("Cost for each iteration")
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.show()

# %% [markdown]
# **Part IV**
#
# Using the final simple linear regression model (the final theta) to predict the mlr_test_X. And then calculate the mse loss between the predictions and the mlr_test_y.

# %%
# calculate the mse loss between the predictions of the mlr_test_X and the mlr_test_y

prediction = np.dot(mlr_test_X, final_theta_mlr)
print("\n")
print("The prediction for mlr: ", prediction)
print("\n")
mse_loss_final = mse_loss(mlr_test_X, mlr_test_y, final_theta_mlr)
print("MSE Loss on MLR test: ", mse_loss_final)
# Out:
# The prediction for mlr:  [  13.77177268   55.70870784  -11.63756147  -41.36745287   42.47178282
#   -89.44736035   29.91386611   26.87047883  -28.9870896    77.31163801
#    11.51195336   15.97769342    4.69147807   92.95078676   96.41853484
#    51.77787013   15.17238072  -87.24324637   61.40896368  -28.68571752
#   -23.81685725  -45.83445494   37.13703998   46.07748806   20.25699458
#    16.54207271  -27.30409938   10.48911801  -64.51176937   78.93655085
#   -21.73294837  -14.94687048   -3.34632281  -43.72273207  -57.64011199
#    19.69484464  -58.21379134  105.74941107  -91.18002396  -29.5727546
#   -55.91290099   94.74913474   -5.29924849  -67.35600436   14.17003148
#     8.65255041   46.68036325   14.54668658  -61.91043039    8.54206515
#    72.80337617   29.54135729  109.49120145 -102.34631984   14.20866627
#    41.59658337   25.68270464   16.8275863   -11.04259705   64.5326738
#   -33.76779272   30.67847736    3.53489552   55.451421    -11.98236363
# ...

# %% [markdown]
# **Question: Based on your experiments, briefly discuss about the performance (MSE loss) and difference between simple linear regression and multiple linear regression.**

# %% [markdown]
# **Answer:**
#
# The SLR model has a lower MSE (4130.071148762847) compared to the MLR model (13198.069718204504).
# Therefore, based on MSE alone, the SLR model appears to perform better on the given dataset.
